# %%
import pandas as pd
data = pd.read_csv('musics.csv')
data
# Out:
#        Unnamed: 0     artist_name  \
# 0               0     David Bowie
# 1               1        Al Green
# 2               2      Elton John
# 3               3     Deep Purple
# 4               4      Carpenters
# ...           ...             ...
# 82010       82010          Maluma
# 82011       82011            ITZY
# 82012       82012         42 Dugg
# 82013       82013      NLE Choppa
# 82014       82014  Arctic Monkeys
#
#                                               track_name  \
# 0                                Starman - 2012 Remaster
# 1                                    Let's Stay Together
# 2      Rocket Man (I Think It's Going To Be A Long, L...
# 3                   Smoke On The Water - Remastered 2012
# 4                                       Top Of The World
# ...                                                  ...
# 82010                                  Nos Comemos Vivos
# 82011                                           SNEAKERS
# 82012                                              IDGAF
# 82013                                        Slut Me Out
# 82014                     There’d Better Be A Mirrorball
#
#                      track_id  year market  track_popularity  \
# 0      0pQskrTITgmCMyr85tb9qq  1972     KR                75
# 1      63xdwScd1Ai1GigAwQxE8y  1972     KR                74
# 2      3gdewACMIVMEWVbyb8O9sY  1972     KR                80
# 3      5MMnwYs0hIxkENRsbkWJ2G  1972     KR                73
# 4      1Ehdm1PDlKrdfyBsjwEvd1  1972     KR                67
# ...                       ...   ...    ...               ...
# 82010  3SlKme42qm1vWrkl3BrZmm  2022     GL                82
# 82011  2WoluqyWzsgRmFCeHeGlnm  2022     GL                79
# 82012  3umPlMokEzAFxJO33tNdlY  2022     GL                69
# 82013  5BmB3OaQyYXCqRyN8iR2Yi  2022     GL                70
# 82014  0yowbJnnbTLpr99f9l1uba  2022     GL                77
#
#                     artist_id danceability energy  ...            type  \
# 0      0oSGxfWSnnOXhD2fKuz2Gy        0.486  0.449  ...  audio_features
# 1      3dkbV4qihUeMsqN4vBGg93        0.756  0.401  ...  audio_features
# 2      3PhoLpVuITZKcymswpck5b        0.601  0.532  ...  audio_features
# 3      568ZhdwyaiCyOGJRtNYhWf        0.598  0.676  ...  audio_features
# 4      1eEfMU2AhEo7XnKgL7c304        0.379  0.343  ...  audio_features
# ...                       ...          ...    ...  ...             ...
# 82010  1r4hJ1h58CWwUQe3MxPuau        0.822  0.719  ...  audio_features
# 82011  2KC9Qb60EaY0kW4eH68vr3        0.935  0.849  ...  audio_features
# 82012  45gHcnDnMC15sgx3VL7ROG        0.514  0.611  ...  audio_features
# 82013  0ErzCpIMyLcjPiwT4elrtZ        0.938  0.606  ...  audio_features
# 82014  7Ln80lUS6He07XvHI8qqHH        0.513  0.369  ...  audio_features
#
#                            id                                   uri  \
# 0      0pQskrTITgmCMyr85tb9qq  spotify:track:0pQskrTITgmCMyr85tb9qq
# 1      63xdwScd1Ai1GigAwQxE8y  spotify:track:63xdwScd1Ai1GigAwQxE8y
# 2      3gdewACMIVMEWVbyb8O9sY  spotify:track:3gdewACMIVMEWVbyb8O9sY
# 3      5MMnwYs0hIxkENRsbkWJ2G  spotify:track:5MMnwYs0hIxkENRsbkWJ2G
# 4      1Ehdm1PDlKrdfyBsjwEvd1  spotify:track:1Ehdm1PDlKrdfyBsjwEvd1
# ...                       ...                                   ...
# 82010  3SlKme42qm1vWrkl3BrZmm  spotify:track:3SlKme42qm1vWrkl3BrZmm
# 82011  2WoluqyWzsgRmFCeHeGlnm  spotify:track:2WoluqyWzsgRmFCeHeGlnm
# 82012  3umPlMokEzAFxJO33tNdlY  spotify:track:3umPlMokEzAFxJO33tNdlY
# 82013  5BmB3OaQyYXCqRyN8iR2Yi  spotify:track:5BmB3OaQyYXCqRyN8iR2Yi
# 82014  0yowbJnnbTLpr99f9l1uba  spotify:track:0yowbJnnbTLpr99f9l1uba
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/0pQskrTITgmC...
# 1      https://api.spotify.com/v1/tracks/63xdwScd1Ai1...
# 2      https://api.spotify.com/v1/tracks/3gdewACMIVME...
# 3      https://api.spotify.com/v1/tracks/5MMnwYs0hIxk...
# 4      https://api.spotify.com/v1/tracks/1Ehdm1PDlKrd...
# ...                                                  ...
# 82010  https://api.spotify.com/v1/tracks/3SlKme42qm1v...
# 82011  https://api.spotify.com/v1/tracks/2WoluqyWzsgR...
# 82012  https://api.spotify.com/v1/tracks/3umPlMokEzAF...
# 82013  https://api.spotify.com/v1/tracks/5BmB3OaQyYXC...
# 82014  https://api.spotify.com/v1/tracks/0yowbJnnbTLp...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/0pQs...      254293
# 1      https://api.spotify.com/v1/audio-analysis/63xd...      199396
# 2      https://api.spotify.com/v1/audio-analysis/3gde...      281613
# 3      https://api.spotify.com/v1/audio-analysis/5MMn...      340742
# 4      https://api.spotify.com/v1/audio-analysis/1Ehd...      179173
# ...                                                  ...         ...
# 82010  https://api.spotify.com/v1/audio-analysis/3SlK...      225366
# 82011  https://api.spotify.com/v1/audio-analysis/2Wol...      179453
# 82012  https://api.spotify.com/v1/audio-analysis/3umP...      138673
# 82013  https://api.spotify.com/v1/audio-analysis/5BmB...      123673
# 82014  https://api.spotify.com/v1/audio-analysis/0yow...      265798
#
#       time_signature      videoId now_id     now
# 0                  4  aBKEt3MhNMM    NaN  5629.0
# 1                  4  COiIC3A0ROM    NaN     NaN
# 2                  4  DtVBCG6ThDk    NaN     NaN
# 3                  4  kjO4UISSkKU    NaN     NaN
# 4                  4  3hyFB6SA7b4    NaN     NaN
# ...              ...          ...    ...     ...
# 82010              4         None    NaN     NaN
# 82011              4         None    NaN     NaN
# 82012              5         None    NaN     NaN
# 82013              4         None    NaN     NaN
# 82014              4         None    NaN     NaN
#
# [82015 rows x 29 columns]

# %%
import requests
import time

# %%
len(data)
# Out:
# 82015

# %%
data
# Out:
#           artist_name                                         track_name  \
# 0         David Bowie                            Starman - 2012 Remaster
# 1            Al Green                                Let's Stay Together
# 2          Elton John  Rocket Man (I Think It's Going To Be A Long, L...
# 3         Deep Purple               Smoke On The Water - Remastered 2012
# 4          Carpenters                                   Top Of The World
# ...               ...                                                ...
# 82010          Maluma                                  Nos Comemos Vivos
# 82011            ITZY                                           SNEAKERS
# 82012         42 Dugg                                              IDGAF
# 82013      NLE Choppa                                        Slut Me Out
# 82014  Arctic Monkeys                     There’d Better Be A Mirrorball
#
#                      track_id  year market  track_popularity  \
# 0      0pQskrTITgmCMyr85tb9qq  1972     KR                75
# 1      63xdwScd1Ai1GigAwQxE8y  1972     KR                74
# 2      3gdewACMIVMEWVbyb8O9sY  1972     KR                80
# 3      5MMnwYs0hIxkENRsbkWJ2G  1972     KR                73
# 4      1Ehdm1PDlKrdfyBsjwEvd1  1972     KR                67
# ...                       ...   ...    ...               ...
# 82010  3SlKme42qm1vWrkl3BrZmm  2022     GL                82
# 82011  2WoluqyWzsgRmFCeHeGlnm  2022     GL                79
# 82012  3umPlMokEzAFxJO33tNdlY  2022     GL                69
# 82013  5BmB3OaQyYXCqRyN8iR2Yi  2022     GL                70
# 82014  0yowbJnnbTLpr99f9l1uba  2022     GL                77
#
#                     artist_id danceability energy key  ... valence    tempo  \
# 0      0oSGxfWSnnOXhD2fKuz2Gy        0.486  0.449   5  ...   0.549  100.456
# 1      3dkbV4qihUeMsqN4vBGg93        0.756  0.401   7  ...   0.514  101.954
# 2      3PhoLpVuITZKcymswpck5b        0.601  0.532  10  ...   0.341  136.571
# 3      568ZhdwyaiCyOGJRtNYhWf        0.598  0.676   0  ...   0.805  114.169
# 4      1eEfMU2AhEo7XnKgL7c304        0.379  0.343  10  ...   0.694  184.301
# ...                       ...          ...    ...  ..  ...     ...      ...
# 82010  1r4hJ1h58CWwUQe3MxPuau        0.822  0.719  10  ...   0.659    82.01
# 82011  2KC9Qb60EaY0kW4eH68vr3        0.935  0.849   7  ...   0.551  119.986
# 82012  45gHcnDnMC15sgx3VL7ROG        0.514  0.611   4  ...   0.311  108.666
# 82013  0ErzCpIMyLcjPiwT4elrtZ        0.938  0.606   6  ...   0.706  121.108
# 82014  7Ln80lUS6He07XvHI8qqHH        0.513  0.369   3  ...   0.311   72.062
#
#                  type                      id  \
# 0      audio_features  0pQskrTITgmCMyr85tb9qq
# 1      audio_features  63xdwScd1Ai1GigAwQxE8y
# 2      audio_features  3gdewACMIVMEWVbyb8O9sY
# 3      audio_features  5MMnwYs0hIxkENRsbkWJ2G
# 4      audio_features  1Ehdm1PDlKrdfyBsjwEvd1
# ...               ...                     ...
# 82010  audio_features  3SlKme42qm1vWrkl3BrZmm
# 82011  audio_features  2WoluqyWzsgRmFCeHeGlnm
# 82012  audio_features  3umPlMokEzAFxJO33tNdlY
# 82013  audio_features  5BmB3OaQyYXCqRyN8iR2Yi
# 82014  audio_features  0yowbJnnbTLpr99f9l1uba
#
#                                         uri  \
# 0      spotify:track:0pQskrTITgmCMyr85tb9qq
# 1      spotify:track:63xdwScd1Ai1GigAwQxE8y
# 2      spotify:track:3gdewACMIVMEWVbyb8O9sY
# 3      spotify:track:5MMnwYs0hIxkENRsbkWJ2G
# 4      spotify:track:1Ehdm1PDlKrdfyBsjwEvd1
# ...                                     ...
# 82010  spotify:track:3SlKme42qm1vWrkl3BrZmm
# 82011  spotify:track:2WoluqyWzsgRmFCeHeGlnm
# 82012  spotify:track:3umPlMokEzAFxJO33tNdlY
# 82013  spotify:track:5BmB3OaQyYXCqRyN8iR2Yi
# 82014  spotify:track:0yowbJnnbTLpr99f9l1uba
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/0pQskrTITgmC...
# 1      https://api.spotify.com/v1/tracks/63xdwScd1Ai1...
# 2      https://api.spotify.com/v1/tracks/3gdewACMIVME...
# 3      https://api.spotify.com/v1/tracks/5MMnwYs0hIxk...
# 4      https://api.spotify.com/v1/tracks/1Ehdm1PDlKrd...
# ...                                                  ...
# 82010  https://api.spotify.com/v1/tracks/3SlKme42qm1v...
# 82011  https://api.spotify.com/v1/tracks/2WoluqyWzsgR...
# 82012  https://api.spotify.com/v1/tracks/3umPlMokEzAF...
# 82013  https://api.spotify.com/v1/tracks/5BmB3OaQyYXC...
# 82014  https://api.spotify.com/v1/tracks/0yowbJnnbTLp...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/0pQs...      254293
# 1      https://api.spotify.com/v1/audio-analysis/63xd...      199396
# 2      https://api.spotify.com/v1/audio-analysis/3gde...      281613
# 3      https://api.spotify.com/v1/audio-analysis/5MMn...      340742
# 4      https://api.spotify.com/v1/audio-analysis/1Ehd...      179173
# ...                                                  ...         ...
# 82010  https://api.spotify.com/v1/audio-analysis/3SlK...      225366
# 82011  https://api.spotify.com/v1/audio-analysis/2Wol...      179453
# 82012  https://api.spotify.com/v1/audio-analysis/3umP...      138673
# 82013  https://api.spotify.com/v1/audio-analysis/5BmB...      123673
# 82014  https://api.spotify.com/v1/audio-analysis/0yow...      265798
#
#       time_signature videoId
# 0                  4    None
# 1                  4    None
# 2                  4    None
# 3                  4    None
# 4                  4    None
# ...              ...     ...
# 82010              4    None
# 82011              4    None
# 82012              5    None
# 82013              4    None
# 82014              4    None
#
# [82015 rows x 26 columns]

# %%
# 유튜브 링크 크롤링 시작 ! 2022.09.16 - 14:59:13

print(int(data.loc[0, 'now'])-1)

for i in range(int(data.loc[0, 'now'])-1, len(data)):

    if data.loc[i, 'videoId'] == 'None':        
        search = data.loc[i, 'artist_name'] + " " + data.loc[i, 'track_name']      
        
        url = "https://www.youtube.com/results?search_query=" + search + "&sp=EgIQAQ%253D%253D"
        response = requests.get(url).text
        
        idx = response.find('webCommandMetadata":{"url":"/watch?v')
        
        if idx == -1:
            data.loc[i, 'videoId'] = 'NO VIDEO'
            print('NO VIDEO', end = "  ===============  ")
            print(i, end = "  ===============  ")
            print(search)
        
        else:
            start = idx + 37
            end = start + 11
            result = response[start:end]
            data.loc[i, 'videoId'] = result
            
            
        if i % 5000 == 0:
            data.to_csv("musics.csv")
            
            
        if i % 200 == 0:
            print(i, end = "  ======  ")
            print(time.strftime('%Y.%m.%d - %H:%M:%S'), end = "  ======  ")
            print(result, end = "  ======  ")
            print(search)
    
        data.loc[0, 'now'] = i
# Out:
# 5628
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12548\1807454991.py in <module>
#       9
#      10         url = "https://www.youtube.com/results?search_query=" + search + "&sp=EgIQAQ%253D%253D"
# ---> 11         response = requests.get(url).text
#      12
#      13         idx = response.find('webCommandMetadata":{"url":"/watch?v')
#
# c:\users\multicampus\appdata\local\programs\python\python37\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# c:\users\multicampus\appdata\local\programs\python\python37\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# c:\users\multicampus\appdata\local\programs\python\python37\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# c:\users\multicampus\appdata\local\programs\python\python37\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     743
#     744         if not stream:
# --> 745             r.content
#     746
#     747         return r
#
# c:\users\multicampus\appdata\local\programs\python\python37\lib\site-packages\requests\models.py in content(self)
#     897                 self._content = None
#     898             else:
# --> 899                 self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     900
#     901         self._content_consumed = True
#
# c:\users\multicampus\appdata\local\programs\python\python37\lib\site-packages\requests\models.py in generate()
#     814             if hasattr(self.raw, "stream"):
#     815                 try:
# --> 816                     yield from self.raw.stream(chunk_size, decode_content=True)
#     817                 except ProtocolError as e:
#     818                     raise ChunkedEncodingError(e)
#
# c:\users\multicampus\appdata\local\programs\python\python37\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     621         """
#     622         if self.chunked and self.supports_chunked_reads():
# --> 623             for line in self.read_chunked(amt, decode_content=decode_content):
#     624                 yield line
#     625         else:
#
# c:\users\multicampus\appdata\local\programs\python\python37\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     813
#     814             while True:
# --> 815                 self._update_chunk_length()
#     816                 if self.chunk_left == 0:
#     817                     break
#
# c:\users\multicampus\appdata\local\programs\python\python37\lib\site-packages\urllib3\response.py in _update_chunk_length(self)
#     743         if self.chunk_left is not None:
#     744             return
# --> 745         line = self._fp.fp.readline()
#     746         line = line.split(b";", 1)[0]
#     747         try:
#
# c:\users\multicampus\appdata\local\programs\python\python37\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# c:\users\multicampus\appdata\local\programs\python\python37\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1047                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1048                   self.__class__)
# -> 1049             return self.read(nbytes, buffer)
#    1050         else:
#    1051             return super().recv_into(buffer, nbytes, flags)
#
# c:\users\multicampus\appdata\local\programs\python\python37\lib\ssl.py in read(self, len, buffer)
#     906         try:
#     907             if buffer is not None:
# --> 908                 return self._sslobj.read(len, buffer)
#     909             else:
#     910                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
i = 10
filename = 'test_' + str(i) + ".csv"
data.to_csv(filename)

# %%
data.to_csv("musics.csv")
